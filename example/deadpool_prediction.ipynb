# %%
from marp import MARP
# Out:
# Loaded 10075 movies that were released prior to 2024. Here's a sample below:

# %%
m = MARP("./imdb_movies.csv")
# Out:
# Loaded 10075 movies that were released prior to 2024. Here's a sample below:

# %%
deadpool = m.predict(
    date='2024-07-26',
    genre=['Action', 'Comedy', 'Superhero', 'Buddy Comedy', 'Adventure'],
    cast=['Ryan Reynolds', 'Hugh Jackman', 'Emma Corrin', 'Matthew Macfadyen',
          'Dafne Keen', 'Jon Favreau', 'Morena Baccarin', 'Rob Delaney', 'Leslie Uggams'],
    lang='English',
    budget=533000000,
    country='US'
)
print("The MARP predicts that it will have an audience rating of ", round(deadpool, 1))
# Out:
# The MARP predicts that it will have an audience rating of  6.6

# %%
m.model.feature_importance
# Out:
#          feature  importance
# 59   lang_Korean    0.124135
# 21     Animation    0.093762
# 79    country_AU    0.077963
# 31         Drama    0.042638
# 108   country_KR    0.039490
# ..           ...         ...
# 114   country_PH    0.000000
# 112   country_NO    0.000000
# 117   country_PY    0.000000
# 126   country_XC    0.000000
# 127   country_ZA    0.000000
#
# [128 rows x 2 columns]

# %%
# m.model.feature_importance_plot()
# Out:
# /workspaces/bsc-compsci-capstone/src/marp/main.py:65: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.barplot(

# %%
# m.model.test_score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 m.model.test_score()
#
# TypeError: 'float' object is not callable
